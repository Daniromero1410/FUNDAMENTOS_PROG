# %% [markdown]
# <a href="https://colab.research.google.com/github/Daniromero1410/FUNDAMENTOS_PROG/blob/Danilo-y-juan/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("=== VETERINARIA VACA Y POLLITO ===")

# Servicios y precios
servicios_canino = {
    "1": ("Peluquería (Baño y Corte)", 50.00),
    "2": ("Consulta Veterinaria", 70.00),
    "3": ("Profilaxis Dental", 250.00),
    "4": ("Paseo (Día)", 25.00),
    "5": ("Guardería (Día)", 40.00),
    "6": ("Entrenamiento (Sesión)", 80.00)
}

servicios_felino = {
    "1": ("Peluquería (Baño y Corte)", 40.00),
    "2": ("Consulta Veterinaria", 70.00),
    "3": ("Profilaxis Dental", 220.00)
}

# Cantidad de mascotas
num_mascotas = int(input("¿Cuántas mascotas desea atender? (máx 3): "))
if num_mascotas > 3:
    num_mascotas = 3

total_caninos = 0.0
total_felinos = 0.0

for i in range(1, num_mascotas + 1):
    print(f"\n--- Mascota {i} ---")
    especie = input("Especie (1=Canino / 2=Felino): ").strip()

    if especie == "1":
        print("Servicios disponibles:")
        for key, (nombre, precio) in servicios_canino.items():
            print(f"  {key}. {nombre} - ${precio:.2f}")
        seleccion = input("Seleccione servicios (ej: 1 2 4): ").strip().split()
        subtotal = sum(servicios_canino[s][1] for s in seleccion if s in servicios_canino)
        total_caninos += subtotal
        print(f"  Subtotal Canino: ${subtotal:.2f}")

    elif especie == "2":
        print("Servicios disponibles:")
        for key, (nombre, precio) in servicios_felino.items():
            print(f"  {key}. {nombre} - ${precio:.2f}")
        seleccion = input("Seleccione servicios (ej: 1 3): ").strip().split()
        subtotal = sum(servicios_felino[s][1] for s in seleccion if s in servicios_felino)
        total_felinos += subtotal
        print(f"  Subtotal Felino: ${subtotal:.2f}")

# Tipo de cliente
tipo = input("\nTipo de cliente (1=Antiguo / 2=Nuevo): ").strip()
descuento_pct = 0.30 if tipo == "1" else 0.10
tipo_nombre = "Antiguo" if tipo == "1" else "Nuevo"
dcto_label = "30%" if tipo == "1" else "10%"

total_bruto = total_caninos + total_felinos
monto_descuento = total_bruto * descuento_pct
total_final = total_bruto - monto_descuento

# Salida
print("\n=================================================")
print(f"Total Bruto Caninos:   ${total_caninos:.2f}")
print(f"Total Bruto Felinos:   ${total_felinos:.2f}")
p
# Out:
# === VETERINARIA VACA Y POLLITO ===
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_16263/3558163310.py in <cell line: 0>()
#      18
#      19 # Cantidad de mascotas
# ---> 20 num_mascotas = int(input("¿Cuántas mascotas desea atender? (máx 3): "))
#      21 if num_mascotas > 3:
#      22     num_mascotas = 3
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
print("=== EL CLOSET DE DARTH VADER ===")

PRECIO_UNITARIO = 25.00

cantidad = int(input("¿Cuántas camisetas desea ordenar? (máx 10): "))
if cantidad > 10:
    cantidad = 10

camisetas = []

for i in range(1, cantidad + 1):
    print(f"\n--- Camiseta {i} ---")
    color  = input("  Color  : ").strip()
    talla  = input("  Talla  : ").strip()
    genero = input("  Género : ").strip()
    camisetas.append((color, talla, genero))

total = cantidad * PRECIO_UNITARIO

# Salida
print("\n=================================================")
print(f"Cantidad Total:      {cantidad}")
print(f"Precio Unitario Fijo: ${PRECIO_UNITARIO:.2f}")
print("-------------------------------------------------")
print("DETALLE POR CAMISETA:")
print("-------------------------------------------------")
for i, (color, talla, genero) in enumerate(camisetas, 1):
    print(f"{i}. Color: {color} | Talla: {talla} | Género: {genero}")
print("-------------------------------------------------")
print(f"TOTAL FINAL A PAGAR: ${total:.2f} ({cantidad} * ${PRECIO_UNITARIO:.2f})")
